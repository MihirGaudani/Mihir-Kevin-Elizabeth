# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv("data.csv")
data
# Out:
#             time  data1  data2  data3  data4  data5  data6  data7  data8  \
# 0   1.739575e+09      0      1      1      0      1      1    180     51
# 1   1.739575e+09      0      1      1      0      1      1    168     50
# 2   1.739575e+09      0      1      1      0      1      1    168     50
# 3   1.739575e+09      0      1      1      0      1      1    168     50
# 4   1.739575e+09      0      1      1      0      1      1    171     53
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 64  1.739575e+09      0      1      1      0      1      1    228     63
# 65  1.739575e+09      0      1      1      0      1      1    228     63
# 66  1.739575e+09      0      1      1      0      1      1    228     63
# 67  1.739575e+09      0      1      1      0      1      1    213     59
# 68  1.739575e+09      0      1      1      0      1      1    213     59
#
#     data9  data10  data11  data12
# 0       8       3       0       0
# ...

# %%
data = data.drop(columns = "time")

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'data1'}>,
#         <Axes: title={'center': 'data2'}>,
#         <Axes: title={'center': 'data3'}>],
#        [<Axes: title={'center': 'data4'}>,
#         <Axes: title={'center': 'data5'}>,
#         <Axes: title={'center': 'data6'}>],
#        [<Axes: title={'center': 'data7'}>,
#         <Axes: title={'center': 'data8'}>,
#         <Axes: title={'center': 'data9'}>],
#        [<Axes: title={'center': 'data10'}>,
#         <Axes: title={'center': 'data11'}>,
#         <Axes: title={'center': 'data12'}>]], dtype=object)
